# %%
library(dash)
library(dashBootstrapComponents)
library(dashHtmlComponents)
library(ggplot2)
library(plotly)
# Out:
# Attaching package: ‘dashBootstrapComponents’
#
#
# The following objects are masked from ‘package:dash’:
#
#     dbcAccordion, dbcAccordionItem, dbcAlert, dbcBadge, dbcBreadcrumb,
#     dbcButton, dbcButtonGroup, dbcCard, dbcCardBody, dbcCardFooter,
#     dbcCardGroup, dbcCardHeader, dbcCardImg, dbcCardImgOverlay,
#     dbcCardLink, dbcCarousel, dbcCheckbox, dbcChecklist, dbcCol,
#     dbcCollapse, dbcContainer, dbcDropdownMenu, dbcDropdownMenuItem,
#     dbcFade, dbcForm, dbcFormFeedback, dbcFormFloating, dbcFormText,
#     dbcInput, dbcInputGroup, dbcInputGroupText, dbcLabel, dbcListGroup,
#     dbcListGroupItem, dbcModal, dbcModalBody, dbcModalFooter,
#     dbcModalHeader, dbcModalTitle, dbcNav, dbcNavItem, dbcNavLink,
#     dbcNavbar, dbcNavbarBrand, dbcNavbarSimple, dbcNavbarToggler,
#     dbcOffcanvas, dbcPagination, dbcPopover, dbcPopoverBody,
#     dbcPopoverHeader, dbcProgress, dbcRadioButton, dbcRadioItems,
#     dbcRow, dbcSelect, dbcSpinner, dbcSwitch, dbcTab, dbcTable,
#     dbcTabs, dbcTextarea, dbcThemes, dbcToast, dbcTooltip
#
#
#
# Attaching package: ‘plotly’
#
#
# The following object is masked from ‘package:ggplot2’:
#
#     last_plot
#
#
# The following object is masked from ‘package:stats’:
#
#     filter
#
#
# The following object is masked from ‘package:graphics’:
#
#     layout

# %%
df = read.csv("data/athlete_events.csv")
head(df)
# Out:
#   ID Name                     Sex Age Height Weight Team           NOC
# 1 1  A Dijiang                M   24  180    80     China          CHN
# 2 2  A Lamusi                 M   23  170    60     China          CHN
# 3 3  Gunnar Nielsen Aaby      M   24   NA    NA     Denmark        DEN
# 4 4  Edgar Lindenau Aabye     M   34   NA    NA     Denmark/Sweden DEN
# 5 5  Christine Jacoba Aaftink F   21  185    82     Netherlands    NED
# 6 5  Christine Jacoba Aaftink F   21  185    82     Netherlands    NED
#   Games       Year Season City      Sport
# 1 1992 Summer 1992 Summer Barcelona Basketball
# 2 2012 Summer 2012 Summer London    Judo
# 3 1920 Summer 1920 Summer Antwerpen Football
# 4 1900 Summer 1900 Summer Paris     Tug-Of-War
# 5 1988 Winter 1988 Winter Calgary   Speed Skating
# 6 1988 Winter 1988 Winter Calgary   Speed Skating
#   Event                              Medal
# 1 Basketball Men's Basketball        NA
# 2 Judo Men's Extra-Lightweight       NA
# 3 Football Men's Football            NA
# 4 Tug-Of-War Men's Tug-Of-War        Gold
# 5 Speed Skating Women's 500 metres   NA
# 6 Speed Skating Women's 1,000 metres NA

# %%
df_new = df %>%
  select(Year, Team, Sport, Medal, Sex) %>%
  filter(Year > 2000, Sport=='Gymnastics')
head(df_new)
# Out:
#   Year Team  Sport      Medal Sex
# 1 2016 Spain Gymnastics NA    M
# 2 2016 Spain Gymnastics NA    M
# 3 2016 Spain Gymnastics NA    M
# 4 2016 Spain Gymnastics NA    M
# 5 2016 Spain Gymnastics NA    M
# 6 2016 Spain Gymnastics NA    M

# %%
df_new <- df_new|>  
#filter( Team == "United States")|>
filter(Medal != "NA")
#drop_na(Medal)
df_new
# Out:
#     Year Team          Sport      Medal  Sex
# 1   2012 Russia        Gymnastics Bronze M
# 2   2012 Russia        Gymnastics Silver M
# 3   2016 Russia        Gymnastics Silver M
# 4   2016 Russia        Gymnastics Silver M
# 5   2016 Russia        Gymnastics Bronze M
# 6   2008 Romania       Gymnastics Bronze F
# 7   2012 Russia        Gymnastics Silver F
# 8   2008 United States Gymnastics Bronze M
# 9   2004 Romania       Gymnastics Gold   F
# 10  2016 Russia        Gymnastics Silver M
# 11  2016 Russia        Gymnastics Bronze M
# 12  2012 Hungary       Gymnastics Gold   M
# 13  2004 United States Gymnastics Silver F
# 14  2008 United States Gymnastics Bronze M
# 15  2016 United States Gymnastics Gold   F
# 16  2016 United States Gymnastics Gold   F
# 17  2016 United States Gymnastics Gold   F
# 18  2016 United States Gymnastics Gold   F
# 19  2016 United States Gymnastics Bronze F
# 20  2008 Poland        Gymnastics Gold   M
# 21  2008 France        Gymnastics Silver M
# 22  2012 Romania       Gymnastics Bronze F
# 23  2008 France        Gymnastics Bronze M
# 24  2004 Italy         Gymnastics Gold   M
# 25  2004 Italy         Gymnastics Bronze M
# 26  2012 Romania       Gymnastics Bronze F
# 27  2008 China         Gymnastics Gold   M
# 28  2008 China         Gymnastics Gold   M
# 29  2012 China         Gymnastics Gold   M
# 30  2012 China         Gymnastics Silver M
# ⋮   ⋮    ⋮             ⋮          ⋮      ⋮
# 247 2012 South Korea   Gymnastics Gold   M
# 248 2004 South Korea   Gymnastics Bronze M
# 249 2008 China         Gymnastics Gold   M
# 250 2008 China         Gymnastics Gold   M
# 251 2008 China         Gymnastics Silver M
# 252 2008 China         Gymnastics Bronze F
# 253 2008 China         Gymnastics Gold   F
# 254 2008 China         Gymnastics Bronze F
# 255 2004 Russia        Gymnastics Bronze F
# 256 2004 Japan         Gymnastics Gold   M
# 257 2004 Japan         Gymnastics Bronze M
# 258 2016 China         Gymnastics Bronze M
# 259 2004 United States Gymnastics Silver M
# 260 2004 Bulgaria      Gymnastics Bronze M
# 261 2004 Bulgaria      Gymnastics Silver M
# 262 2008 South Korea   Gymnastics Silver M
# 263 2004 Russia        Gymnastics Bronze F
# 264 2012 Brazil        Gymnastics Gold   M
# 265 2016 Brazil        Gymnastics Silver M
# 266 2012 China         Gymnastics Gold   M
# 267 2016 China         Gymnastics Bronze M
# 268 2004 China         Gymnastics Bronze F
# 269 2004 Russia        Gymnastics Bronze F
# 270 2012 Netherlands   Gymnastics Gold   M
# 271 2008 China         Gymnastics Gold   M
# 272 2008 China         Gymnastics Gold   M
# 273 2008 China         Gymnastics Gold   M
# 274 2012 China         Gymnastics Gold   M
# 275 2012 China         Gymnastics Gold   M
# 276 2012 China         Gymnastics Bronze M

# %%
#plot <- function(col) {
p <- ggplot(df_new |>
           filter(Year==2004, Team=="United States")) +
    aes(x = Medal,
        color = Sex,
        fill = Sex,
       ) +
    geom_bar(position = 'dodge') +
    ggthemes::scale_color_tableau()
#ggplotly(p)
    #}

# %%
c(unique(df_new$Year))
# Out:
# [1] 2012 2016 2008 2004

# %%
str(df_new)
# Out:
# 'data.frame':	276 obs. of  5 variables:
#  $ Year : int  2012 2012 2016 2016 2016 2008 2012 2008 2004 2016 ...
#  $ Team : chr  "Russia" "Russia" "Russia" "Russia" ...
#  $ Sport: chr  "Gymnastics" "Gymnastics" "Gymnastics" "Gymnastics" ...
#  $ Medal: chr  "Bronze" "Silver" "Silver" "Silver" ...
#  $ Sex  : chr  "M" "M" "M" "M" ...

# %%
p
# Out:
# plot without title

# %%
result <- plot
